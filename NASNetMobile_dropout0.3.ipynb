# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
modelname="NASNetMobile_dropout0.3"
LR=0.001
DO=0.3

# %%
foldernames_to_id={"VeryMildDemented":1, "NonDemented":0, "ModerateDemented":2, "MildDemented":3}
import os
import torch

# %%
from PIL import Image
from numpy import asarray
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from keras import layers,models
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, Flatten, MaxPooling2D, Dense, Dropout, GlobalAveragePooling2D
from keras import optimizers, losses
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path
import os.path
from sklearn.metrics import classification_report, confusion_matrix
import itertools

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
    validation_split=0.1) # set validation split

# %%
foldername='/content/drive/My Drive/ml_project/Dataset/'
train_images = train_datagen.flow_from_directory(
    foldername,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    subset='training') # set as training data

validation_images = train_datagen.flow_from_directory(
    foldername , # same directory as training data
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    subset='validation') # set as validation data
# Out:
# Found 30586 images belonging to 4 classes.
# Found 3398 images belonging to 4 classes.

# %%
def create_model():
  mymodel = Sequential()

  pretrained_model= tf.keras.applications.NASNetMobile(include_top=False,
                   input_shape=(224,224,3),
                   pooling='avg',classes=4,
                   weights='imagenet')
  for layer in pretrained_model.layers:
        layer.trainable=False

  mymodel.add(pretrained_model)

  mymodel.add(Flatten())
  mymodel.add(Dense(512, activation='relu'))
  mymodel.add(Dropout(DO))
  mymodel.add(Dense(4, activation='softmax'))
  mymodel.compile(loss = 'categorical_crossentropy', optimizer = tf.keras.optimizers.Adam(lr=LR), metrics = ['accuracy'])
  return mymodel

# %%
# Create a basic model instance
model = create_model()

# Display the model's architecture
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  NASNet (Functional)         (None, 1056)              4269716
#
#  flatten_1 (Flatten)         (None, 1056)              0
#
#  dense_2 (Dense)             (None, 512)               541184
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 4)                 2052
#
# =================================================================
# Total params: 4,812,952
# Trainable params: 543,236
# Non-trainable params: 4,269,716
# _________________________________________________________________

# %%
checkpointdir='/content/drive/My Drive/ml_project/Checkpoints/'
checkpoint_path = checkpointdir+modelname+"training_1/cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

# %%
#model.load_weights(checkpoint_path)

# %%
batch_size = 32
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path, 
    verbose=1, 
    save_best_only=True,
    save_weights_only=True)

# %%
# Evaluate the model
#loss, acc = model.evaluate(validation_images, verbose=2)
#print("Untrained model, accuracy: {:5.2f}%".format(100 * acc))

# %%
history = model.fit(train_images,
    steps_per_epoch=len(train_images),
    validation_data=validation_images,
    validation_steps=len(validation_images),
    epochs=300,
    callbacks=[cp_callback])
# Out:
# Epoch 1/300
# 956/956 [==============================] - ETA: 0s - loss: 0.9992 - accuracy: 0.5445
# Epoch 1: val_loss improved from inf to 0.79684, saving model to /content/drive/My Drive/ml_project/Checkpoints/NASNetMobile_dropout0.3training_1/cp.ckpt
# 956/956 [==============================] - 3663s 4s/step - loss: 0.9992 - accuracy: 0.5445 - val_loss: 0.7968 - val_accuracy: 0.6327
# Epoch 2/300
# 956/956 [==============================] - ETA: 0s - loss: 0.8254 - accuracy: 0.6233
# Epoch 2: val_loss improved from 0.79684 to 0.76889, saving model to /content/drive/My Drive/ml_project/Checkpoints/NASNetMobile_dropout0.3training_1/cp.ckpt
# 956/956 [==============================] - 123s 128ms/step - loss: 0.8254 - accuracy: 0.6233 - val_loss: 0.7689 - val_accuracy: 0.6457
# Epoch 3/300
# 956/956 [==============================] - ETA: 0s - loss: 0.7671 - accuracy: 0.6522
# Epoch 3: val_loss improved from 0.76889 to 0.70081, saving model to /content/drive/My Drive/ml_project/Checkpoints/NASNetMobile_dropout0.3training_1/cp.ckpt
# 956/956 [==============================] - 122s 128ms/step - loss: 0.7671 - accuracy: 0.6522 - val_loss: 0.7008 - val_accuracy: 0.6780
# Epoch 4/300
# 956/956 [==============================] - ETA: 0s - loss: 0.7195 - accuracy: 0.6734
# Epoch 4: val_loss improved from 0.70081 to 0.65586, saving model to /content/drive/My Drive/ml_project/Checkpoints/NASNetMobile_dropout0.3training_1/cp.ckpt
# 956/956 [==============================] - 120s 126ms/step - loss: 0.7195 - accuracy: 0.6734 - val_loss: 0.6559 - val_accuracy: 0.7042
# Epoch 5/300
# 956/956 [==============================] - ETA: 0s - loss: 0.6918 - accuracy: 0.6902
# Epoch 5: val_loss improved from 0.65586 to 0.63070, saving model to /content/drive/My Drive/ml_project/Checkpoints/NASNetMobile_dropout0.3training_1/cp.ckpt
# 956/956 [==============================] - 120s 126ms/step - loss: 0.6918 - accuracy: 0.6902 - val_loss: 0.6307 - val_accuracy: 0.7107
# Epoch 6/300
# 956/956 [==============================] - ETA: 0s - loss: 0.6597 - accuracy: 0.7049
# Epoch 6: val_loss improved from 0.63070 to 0.62803, saving model to /content/drive/My Drive/ml_project/Checkpoints/NASNetMobile_dropout0.3training_1/cp.ckpt
# 956/956 [==============================] - 120s 126ms/step - loss: 0.6597 - accuracy: 0.7049 - val_loss: 0.6280 - val_accuracy: 0.7207
# Epoch 7/300
# 956/956 [==============================] - ETA: 0s - loss: 0.6314 - accuracy: 0.7178
# Epoch 7: val_loss did not improve from 0.62803
# 956/956 [==============================] - 120s 125ms/step - loss: 0.6314 - accuracy: 0.7178 - val_loss: 0.6314 - val_accuracy: 0.7187
# Epoch 8/300
# 956/956 [==============================] - ETA: 0s - loss: 0.6107 - accuracy: 0.7312
# Epoch 8: val_loss improved from 0.62803 to 0.58817, saving model to /content/drive/My Drive/ml_project/Checkpoints/NASNetMobile_dropout0.3training_1/cp.ckpt
# 956/956 [==============================] - 120s 125ms/step - loss: 0.6107 - accuracy: 0.7312 - val_loss: 0.5882 - val_accuracy: 0.7378
# Epoch 9/300
# 956/956 [==============================] - ETA: 0s - loss: 0.5955 - accuracy: 0.7360
# Epoch 9: val_loss improved from 0.58817 to 0.55617, saving model to /content/drive/My Drive/ml_project/Checkpoints/NASNetMobile_dropout0.3training_1/cp.ckpt
# 956/956 [==============================] - 120s 125ms/step - loss: 0.5955 - accuracy: 0.7360 - val_loss: 0.5562 - val_accuracy: 0.7566
# Epoch 10/300
# 956/956 [==============================] - ETA: 0s - loss: 0.5803 - accuracy: 0.7450
# Epoch 10: val_loss improved from 0.55617 to 0.53654, saving model to /content/drive/My Drive/ml_project/Checkpoints/NASNetMobile_dropout0.3training_1/cp.ckpt
# 956/956 [==============================] - 120s 125ms/step - loss: 0.5803 - accuracy: 0.7450 - val_loss: 0.5365 - val_accuracy: 0.7684
# Epoch 11/300
# 956/956 [==============================] - ETA: 0s - loss: 0.5606 - accuracy: 0.7536
# Epoch 11: val_loss did not improve from 0.53654
# 956/956 [==============================] - 120s 125ms/step - loss: 0.5606 - accuracy: 0.7536 - val_loss: 0.5408 - val_accuracy: 0.7646
# Epoch 12/300
# 956/956 [==============================] - ETA: 0s - loss: 0.5415 - accuracy: 0.7631
# Epoch 12: val_loss improved from 0.53654 to 0.51283, saving model to /content/drive/My Drive/ml_project/Checkpoints/NASNetMobile_dropout0.3training_1/cp.ckpt
# 956/956 [==============================] - 120s 125ms/step - loss: 0.5415 - accuracy: 0.7631 - val_loss: 0.5128 - val_accuracy: 0.7810
# Epoch 13/300
# 956/956 [==============================] - ETA: 0s - loss: 0.5330 - accuracy: 0.7672
# Epoch 13: val_loss did not improve from 0.51283
# 956/956 [==============================] - 118s 123ms/step - loss: 0.5330 - accuracy: 0.7672 - val_loss: 0.5293 - val_accuracy: 0.7649
# Epoch 14/300
# 956/956 [==============================] - ETA: 0s - loss: 0.5155 - accuracy: 0.7767
# Epoch 14: val_loss improved from 0.51283 to 0.50287, saving model to /content/drive/My Drive/ml_project/Checkpoints/NASNetMobile_dropout0.3training_1/cp.ckpt
# 956/956 [==============================] - 119s 125ms/step - loss: 0.5155 - accuracy: 0.7767 - val_loss: 0.5029 - val_accuracy: 0.7840
# Epoch 15/300
# 956/956 [==============================] - ETA: 0s - loss: 0.5028 - accuracy: 0.7830
# Epoch 15: val_loss improved from 0.50287 to 0.49717, saving model to /content/drive/My Drive/ml_project/Checkpoints/NASNetMobile_dropout0.3training_1/cp.ckpt
# 956/956 [==============================] - 120s 125ms/step - loss: 0.5028 - accuracy: 0.7830 - val_loss: 0.4972 - val_accuracy: 0.7869
# Epoch 16/300
# 956/956 [==============================] - ETA: 0s - loss: 0.5009 - accuracy: 0.7829
# Epoch 16: val_loss improved from 0.49717 to 0.49651, saving model to /content/drive/My Drive/ml_project/Checkpoints/NASNetMobile_dropout0.3training_1/cp.ckpt
# 956/956 [==============================] - 119s 125ms/step - loss: 0.5009 - accuracy: 0.7829 - val_loss: 0.4965 - val_accuracy: 0.7878
# Epoch 17/300
# 956/956 [==============================] - ETA: 0s - loss: 0.4821 - accuracy: 0.7908
# Epoch 17: val_loss improved from 0.49651 to 0.48906, saving model to /content/drive/My Drive/ml_project/Checkpoints/NASNetMobile_dropout0.3training_1/cp.ckpt
# 956/956 [==============================] - 118s 123ms/step - loss: 0.4821 - accuracy: 0.7908 - val_loss: 0.4891 - val_accuracy: 0.7855
# Epoch 18/300
# 956/956 [==============================] - ETA: 0s - loss: 0.4759 - accuracy: 0.7947
# Epoch 18: val_loss improved from 0.48906 to 0.47674, saving model to /content/drive/My Drive/ml_project/Checkpoints/NASNetMobile_dropout0.3training_1/cp.ckpt
# 956/956 [==============================] - 120s 125ms/step - loss: 0.4759 - accuracy: 0.7947 - val_loss: 0.4767 - val_accuracy: 0.7943
# Epoch 19/300
# 956/956 [==============================] - ETA: 0s - loss: 0.4624 - accuracy: 0.8014
# Epoch 19: val_loss did not improve from 0.47674
# 956/956 [==============================] - 120s 126ms/step - loss: 0.4624 - accuracy: 0.8014 - val_loss: 0.4778 - val_accuracy: 0.7893
# Epoch 20/300
# 956/956 [==============================] - ETA: 0s - loss: 0.4526 - accuracy: 0.8079
# Epoch 20: val_loss improved from 0.47674 to 0.47275, saving model to /content/drive/My Drive/ml_project/Checkpoints/NASNetMobile_dropout0.3training_1/cp.ckpt
# 956/956 [==============================] - 130s 136ms/step - loss: 0.4526 - accuracy: 0.8079 - val_loss: 0.4728 - val_accuracy: 0.8028
# Epoch 21/300
# 956/956 [==============================] - ETA: 0s - loss: 0.4415 - accuracy: 0.8141
# Epoch 21: val_loss improved from 0.47275 to 0.46079, saving model to /content/drive/My Drive/ml_project/Checkpoints/NASNetMobile_dropout0.3training_1/cp.ckpt
# 956/956 [==============================] - 122s 127ms/step - loss: 0.4415 - accuracy: 0.8141 - val_loss: 0.4608 - val_accuracy: 0.8058
# Epoch 22/300
# 956/956 [==============================] - ETA: 0s - loss: 0.4406 - accuracy: 0.8136
# Epoch 22: val_loss improved from 0.46079 to 0.44554, saving model to /content/drive/My Drive/ml_project/Checkpoints/NASNetMobile_dropout0.3training_1/cp.ckpt
# 956/956 [==============================] - 120s 125ms/step - loss: 0.4406 - accuracy: 0.8136 - val_loss: 0.4455 - val_accuracy: 0.8152
# Epoch 23/300
# 956/956 [==============================] - ETA: 0s - loss: 0.4294 - accuracy: 0.8169
# Epoch 23: val_loss did not improve from 0.44554
# 956/956 [==============================] - 121s 126ms/step - loss: 0.4294 - accuracy: 0.8169 - val_loss: 0.4517 - val_accuracy: 0.8093
# Epoch 24/300
# 956/956 [==============================] - ETA: 0s - loss: 0.4245 - accuracy: 0.8220
# Epoch 24: val_loss improved from 0.44554 to 0.44001, saving model to /content/drive/My Drive/ml_project/Checkpoints/NASNetMobile_dropout0.3training_1/cp.ckpt
# 956/956 [==============================] - 121s 127ms/step - loss: 0.4245 - accuracy: 0.8220 - val_loss: 0.4400 - val_accuracy: 0.8167
# Epoch 25/300
# 956/956 [==============================] - ETA: 0s - loss: 0.4151 - accuracy: 0.8249
# Epoch 25: val_loss improved from 0.44001 to 0.43422, saving model to /content/drive/My Drive/ml_project/Checkpoints/NASNetMobile_dropout0.3training_1/cp.ckpt
# 956/956 [==============================] - 121s 127ms/step - loss: 0.4151 - accuracy: 0.8249 - val_loss: 0.4342 - val_accuracy: 0.8178
# Epoch 26/300
# 956/956 [==============================] - ETA: 0s - loss: 0.4033 - accuracy: 0.8307
# Epoch 26: val_loss improved from 0.43422 to 0.42687, saving model to /content/drive/My Drive/ml_project/Checkpoints/NASNetMobile_dropout0.3training_1/cp.ckpt
# 956/956 [==============================] - 120s 125ms/step - loss: 0.4033 - accuracy: 0.8307 - val_loss: 0.4269 - val_accuracy: 0.8140
# Epoch 27/300
# 956/956 [==============================] - ETA: 0s - loss: 0.3962 - accuracy: 0.8336
# Epoch 27: val_loss did not improve from 0.42687
# 956/956 [==============================] - 120s 126ms/step - loss: 0.3962 - accuracy: 0.8336 - val_loss: 0.4388 - val_accuracy: 0.8214
# Epoch 28/300
# 956/956 [==============================] - ETA: 0s - loss: 0.3971 - accuracy: 0.8325
# Epoch 28: val_loss did not improve from 0.42687
# 956/956 [==============================] - 120s 125ms/step - loss: 0.3971 - accuracy: 0.8325 - val_loss: 0.4389 - val_accuracy: 0.8131
# Epoch 29/300
# 956/956 [==============================] - ETA: 0s - loss: 0.3860 - accuracy: 0.8362
# Epoch 29: val_loss did not improve from 0.42687
# 956/956 [==============================] - 120s 126ms/step - loss: 0.3860 - accuracy: 0.8362 - val_loss: 0.4431 - val_accuracy: 0.8164
# Epoch 30/300
# 956/956 [==============================] - ETA: 0s - loss: 0.3744 - accuracy: 0.8420
# Epoch 30: val_loss did not improve from 0.42687
# 956/956 [==============================] - 118s 124ms/step - loss: 0.3744 - accuracy: 0.8420 - val_loss: 0.4345 - val_accuracy: 0.8205
# Epoch 31/300
# 956/956 [==============================] - ETA: 0s - loss: 0.3774 - accuracy: 0.8431
# Epoch 31: val_loss improved from 0.42687 to 0.41928, saving model to /content/drive/My Drive/ml_project/Checkpoints/NASNetMobile_dropout0.3training_1/cp.ckpt
# 956/956 [==============================] - 120s 125ms/step - loss: 0.3774 - accuracy: 0.8431 - val_loss: 0.4193 - val_accuracy: 0.8343
# Epoch 32/300
# 956/956 [==============================] - ETA: 0s - loss: 0.3674 - accuracy: 0.8468
# Epoch 32: val_loss did not improve from 0.41928
# 956/956 [==============================] - 121s 126ms/step - loss: 0.3674 - accuracy: 0.8468 - val_loss: 0.4238 - val_accuracy: 0.8172
# Epoch 33/300
# 956/956 [==============================] - ETA: 0s - loss: 0.3605 - accuracy: 0.8494
# Epoch 33: val_loss improved from 0.41928 to 0.41194, saving model to /content/drive/My Drive/ml_project/Checkpoints/NASNetMobile_dropout0.3training_1/cp.ckpt
# 956/956 [==============================] - 122s 128ms/step - loss: 0.3605 - accuracy: 0.8494 - val_loss: 0.4119 - val_accuracy: 0.8349
# Epoch 34/300
# 956/956 [==============================] - ETA: 0s - loss: 0.3573 - accuracy: 0.8502
# Epoch 34: val_loss did not improve from 0.41194
# 956/956 [==============================] - 120s 126ms/step - loss: 0.3573 - accuracy: 0.8502 - val_loss: 0.4155 - val_accuracy: 0.8273
# Epoch 35/300
# 956/956 [==============================] - ETA: 0s - loss: 0.3555 - accuracy: 0.8519
# Epoch 35: val_loss did not improve from 0.41194
# 956/956 [==============================] - 120s 126ms/step - loss: 0.3555 - accuracy: 0.8519 - val_loss: 0.4197 - val_accuracy: 0.8311
# Epoch 36/300
# 956/956 [==============================] - ETA: 0s - loss: 0.3447 - accuracy: 0.8567
# Epoch 36: val_loss improved from 0.41194 to 0.38790, saving model to /content/drive/My Drive/ml_project/Checkpoints/NASNetMobile_dropout0.3training_1/cp.ckpt
# 956/956 [==============================] - 120s 126ms/step - loss: 0.3447 - accuracy: 0.8567 - val_loss: 0.3879 - val_accuracy: 0.8449
# Epoch 37/300
# 956/956 [==============================] - ETA: 0s - loss: 0.3422 - accuracy: 0.8568
# Epoch 37: val_loss did not improve from 0.38790
# 956/956 [==============================] - 120s 126ms/step - loss: 0.3422 - accuracy: 0.8568 - val_loss: 0.4049 - val_accuracy: 0.8370
# Epoch 38/300
# 956/956 [==============================] - ETA: 0s - loss: 0.3364 - accuracy: 0.8591
# Epoch 38: val_loss did not improve from 0.38790
# 956/956 [==============================] - 129s 135ms/step - loss: 0.3364 - accuracy: 0.8591 - val_loss: 0.4147 - val_accuracy: 0.8328
# Epoch 39/300
# 956/956 [==============================] - ETA: 0s - loss: 0.3353 - accuracy: 0.8611
# Epoch 39: val_loss did not improve from 0.38790
# 956/956 [==============================] - 120s 126ms/step - loss: 0.3353 - accuracy: 0.8611 - val_loss: 0.4018 - val_accuracy: 0.8355
# Epoch 40/300
# 956/956 [==============================] - ETA: 0s - loss: 0.3265 - accuracy: 0.8637
# Epoch 40: val_loss did not improve from 0.38790
# 956/956 [==============================] - 120s 126ms/step - loss: 0.3265 - accuracy: 0.8637 - val_loss: 0.4103 - val_accuracy: 0.8311
# Epoch 41/300
# 956/956 [==============================] - ETA: 0s - loss: 0.3291 - accuracy: 0.8623
# Epoch 41: val_loss did not improve from 0.38790
# 956/956 [==============================] - 119s 124ms/step - loss: 0.3291 - accuracy: 0.8623 - val_loss: 0.4043 - val_accuracy: 0.8323
# Epoch 42/300
# 956/956 [==============================] - ETA: 0s - loss: 0.3174 - accuracy: 0.8673
# Epoch 42: val_loss did not improve from 0.38790
# 956/956 [==============================] - 120s 126ms/step - loss: 0.3174 - accuracy: 0.8673 - val_loss: 0.4058 - val_accuracy: 0.8376
# Epoch 43/300
# 956/956 [==============================] - ETA: 0s - loss: 0.3161 - accuracy: 0.8702
# Epoch 43: val_loss did not improve from 0.38790
# 956/956 [==============================] - 120s 125ms/step - loss: 0.3161 - accuracy: 0.8702 - val_loss: 0.3989 - val_accuracy: 0.8414
# Epoch 44/300
# 956/956 [==============================] - ETA: 0s - loss: 0.3087 - accuracy: 0.8726
# Epoch 44: val_loss did not improve from 0.38790
# 956/956 [==============================] - 120s 125ms/step - loss: 0.3087 - accuracy: 0.8726 - val_loss: 0.4083 - val_accuracy: 0.8396
# Epoch 45/300
# 956/956 [==============================] - ETA: 0s - loss: 0.3074 - accuracy: 0.8735
# Epoch 45: val_loss did not improve from 0.38790
# 956/956 [==============================] - 119s 125ms/step - loss: 0.3074 - accuracy: 0.8735 - val_loss: 0.3991 - val_accuracy: 0.8355
# Epoch 46/300
# 956/956 [==============================] - ETA: 0s - loss: 0.3078 - accuracy: 0.8736
# Epoch 46: val_loss did not improve from 0.38790
# 956/956 [==============================] - 118s 124ms/step - loss: 0.3078 - accuracy: 0.8736 - val_loss: 0.3962 - val_accuracy: 0.8411
# Epoch 47/300
# 956/956 [==============================] - ETA: 0s - loss: 0.2982 - accuracy: 0.8771
# Epoch 47: val_loss did not improve from 0.38790
# 956/956 [==============================] - 120s 125ms/step - loss: 0.2982 - accuracy: 0.8771 - val_loss: 0.4176 - val_accuracy: 0.8408
# Epoch 48/300
# 956/956 [==============================] - ETA: 0s - loss: 0.3027 - accuracy: 0.8721
# Epoch 48: val_loss did not improve from 0.38790
# 956/956 [==============================] - 119s 125ms/step - loss: 0.3027 - accuracy: 0.8721 - val_loss: 0.3962 - val_accuracy: 0.8455
# Epoch 49/300
# 956/956 [==============================] - ETA: 0s - loss: 0.2895 - accuracy: 0.8796
# Epoch 49: val_loss improved from 0.38790 to 0.38191, saving model to /content/drive/My Drive/ml_project/Checkpoints/NASNetMobile_dropout0.3training_1/cp.ckpt
# 956/956 [==============================] - 120s 125ms/step - loss: 0.2895 - accuracy: 0.8796 - val_loss: 0.3819 - val_accuracy: 0.8476
# Epoch 50/300
# 956/956 [==============================] - ETA: 0s - loss: 0.2873 - accuracy: 0.8798
# Epoch 50: val_loss did not improve from 0.38191
# 956/956 [==============================] - 121s 126ms/step - loss: 0.2873 - accuracy: 0.8798 - val_loss: 0.4044 - val_accuracy: 0.8408
# Epoch 51/300
# 956/956 [==============================] - ETA: 0s - loss: 0.2847 - accuracy: 0.8815
# Epoch 51: val_loss did not improve from 0.38191
# 956/956 [==============================] - 120s 125ms/step - loss: 0.2847 - accuracy: 0.8815 - val_loss: 0.3835 - val_accuracy: 0.8428
# Epoch 52/300
# 956/956 [==============================] - ETA: 0s - loss: 0.2840 - accuracy: 0.8827
# Epoch 52: val_loss did not improve from 0.38191
# 956/956 [==============================] - 121s 126ms/step - loss: 0.2840 - accuracy: 0.8827 - val_loss: 0.3863 - val_accuracy: 0.8481
# Epoch 53/300
# 956/956 [==============================] - ETA: 0s - loss: 0.2772 - accuracy: 0.8865
# Epoch 53: val_loss did not improve from 0.38191
# 956/956 [==============================] - 120s 126ms/step - loss: 0.2772 - accuracy: 0.8865 - val_loss: 0.3970 - val_accuracy: 0.8534
# Epoch 54/300
# 956/956 [==============================] - ETA: 0s - loss: 0.2795 - accuracy: 0.8847
# Epoch 54: val_loss did not improve from 0.38191
# 956/956 [==============================] - 120s 126ms/step - loss: 0.2795 - accuracy: 0.8847 - val_loss: 0.4010 - val_accuracy: 0.8467
# Epoch 55/300
# 956/956 [==============================] - ETA: 0s - loss: 0.2806 - accuracy: 0.8854
# Epoch 55: val_loss did not improve from 0.38191
# 956/956 [==============================] - 121s 126ms/step - loss: 0.2806 - accuracy: 0.8854 - val_loss: 0.4003 - val_accuracy: 0.8440
# Epoch 56/300
# 956/956 [==============================] - ETA: 0s - loss: 0.2740 - accuracy: 0.8856
# Epoch 56: val_loss improved from 0.38191 to 0.37399, saving model to /content/drive/My Drive/ml_project/Checkpoints/NASNetMobile_dropout0.3training_1/cp.ckpt
# 956/956 [==============================] - 122s 128ms/step - loss: 0.2740 - accuracy: 0.8856 - val_loss: 0.3740 - val_accuracy: 0.8508
# Epoch 57/300
# 956/956 [==============================] - ETA: 0s - loss: 0.2654 - accuracy: 0.8917
# Epoch 57: val_loss did not improve from 0.37399
# 956/956 [==============================] - 121s 126ms/step - loss: 0.2654 - accuracy: 0.8917 - val_loss: 0.3812 - val_accuracy: 0.8496
# Epoch 58/300
# 956/956 [==============================] - ETA: 0s - loss: 0.2669 - accuracy: 0.8888
# Epoch 58: val_loss did not improve from 0.37399
# 956/956 [==============================] - 120s 126ms/step - loss: 0.2669 - accuracy: 0.8888 - val_loss: 0.4021 - val_accuracy: 0.8458
# Epoch 59/300
# 956/956 [==============================] - ETA: 0s - loss: 0.2646 - accuracy: 0.8912
# Epoch 59: val_loss did not improve from 0.37399
# 956/956 [==============================] - 120s 126ms/step - loss: 0.2646 - accuracy: 0.8912 - val_loss: 0.3754 - val_accuracy: 0.8549
# Epoch 60/300
# 956/956 [==============================] - ETA: 0s - loss: 0.2671 - accuracy: 0.8903
# Epoch 60: val_loss did not improve from 0.37399
# 956/956 [==============================] - 120s 126ms/step - loss: 0.2671 - accuracy: 0.8903 - val_loss: 0.3994 - val_accuracy: 0.8426
# Epoch 61/300
# 956/956 [==============================] - ETA: 0s - loss: 0.2595 - accuracy: 0.8936
# Epoch 61: val_loss did not improve from 0.37399
# 956/956 [==============================] - 120s 125ms/step - loss: 0.2595 - accuracy: 0.8936 - val_loss: 0.3865 - val_accuracy: 0.8561
# Epoch 62/300
# 956/956 [==============================] - ETA: 0s - loss: 0.2562 - accuracy: 0.8933
# Epoch 62: val_loss did not improve from 0.37399
# 956/956 [==============================] - 120s 126ms/step - loss: 0.2562 - accuracy: 0.8933 - val_loss: 0.4005 - val_accuracy: 0.8423
# Epoch 63/300
# 956/956 [==============================] - ETA: 0s - loss: 0.2468 - accuracy: 0.9004
# Epoch 63: val_loss did not improve from 0.37399
# 956/956 [==============================] - 120s 126ms/step - loss: 0.2468 - accuracy: 0.9004 - val_loss: 0.3762 - val_accuracy: 0.8596
# Epoch 64/300
# 956/956 [==============================] - ETA: 0s - loss: 0.2512 - accuracy: 0.8953
# Epoch 64: val_loss did not improve from 0.37399
# 956/956 [==============================] - 120s 126ms/step - loss: 0.2512 - accuracy: 0.8953 - val_loss: 0.4129 - val_accuracy: 0.8428
# Epoch 65/300
# 651/956 [===================>..........] - ETA: 34s - loss: 0.2480 - accuracy: 0.8974

# %%
#Accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# 2 following cells are for loading latest trained models

# %%
# Create a basic model instance
#model = create_model()

# Evaluate the model
#loss, acc = model.evaluate(validation_images, verbose=2)
#print("Untrained model, accuracy: {:5.2f}%".format(100 * acc))

# %%
# Loads the weights
#p = checkpointdir+modelname+"-training/cp-"

#fill in the best model filename like 0004
#best_checkpoint_path=p+""+"".ckpt"
#latest = tf.train.latest_checkpoint(checkpoint_dir)
#model.load_weights(latest)

# Re-evaluate the model
#loss, acc = model.evaluate(validation_images, verbose=2)
#print("Restored model, accuracy: {:5.2f}%".format(100 * acc))

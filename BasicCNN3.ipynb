# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
foldernames_to_id={"VeryMildDemented":1, "NonDemented":0, "ModerateDemented":2, "MildDemented":3}
import os
import torch

# %%
modelname="BasicCNN3"
LR=0.001
DO=0.2

# %%
from PIL import Image
from numpy import asarray
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from keras import layers,models
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, Flatten, MaxPooling2D, Dense, Dropout, GlobalAveragePooling2D
from keras import optimizers, losses
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path
import os.path
from sklearn.metrics import classification_report, confusion_matrix
import itertools

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
    validation_split=0.1) # set validation split

# %%
foldername='/content/drive/My Drive/ml_project/Dataset/'
train_images = train_datagen.flow_from_directory(
    foldername,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    subset='training') # set as training data

validation_images = train_datagen.flow_from_directory(
    foldername , # same directory as training data
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    subset='validation') # set as validation data
# Out:
# Found 30586 images belonging to 4 classes.
# Found 3398 images belonging to 4 classes.

# %%
def create_model():
  model = tf.keras.models.Sequential([
    Conv2D(32, (3,3), activation = 'relu', input_shape = (224,224, 3)),
    MaxPooling2D(2,2),
    Conv2D(32, (3,3), activation = 'relu'),
    MaxPooling2D(2,2),
    Conv2D(32, (3,3), activation = 'relu'),
    MaxPooling2D(2,2),
    Dropout(0.2),
    Conv2D(32, (3,3), activation = 'relu'),
    MaxPooling2D(2,2),
    Flatten(),
    Dropout(0.2),
    Dense(256, activation = 'relu'),
    Dropout(0.2),
    Dense(4, activation = 'softmax')
])
  model.compile(loss = 'categorical_crossentropy', optimizer = tf.keras.optimizers.Adam(), metrics = ['accuracy'])
  return model

# %%
# Create a basic model instance
model = create_model()

# Display the model's architecture
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 222, 222, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 111, 111, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 109, 109, 32)      9248
#
#  max_pooling2d_1 (MaxPooling  (None, 54, 54, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 52, 52, 32)        9248
#
#  max_pooling2d_2 (MaxPooling  (None, 26, 26, 32)       0
#  2D)
#
#  dropout (Dropout)           (None, 26, 26, 32)        0
#
#  conv2d_3 (Conv2D)           (None, 24, 24, 32)        9248
#
#  max_pooling2d_3 (MaxPooling  (None, 12, 12, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 4608)              0
#
#  dropout_1 (Dropout)         (None, 4608)              0
#
#  dense (Dense)               (None, 256)               1179904
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 4)                 1028
#
# =================================================================
# Total params: 1,209,572
# Trainable params: 1,209,572
# Non-trainable params: 0
# _________________________________________________________________

# %%
checkpointdir='/content/drive/My Drive/ml_project/Checkpoints/'
checkpoint_path = checkpointdir+modelname+"training_1/cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

# %%
#model.load_weights(checkpoint_path)

# %%
batch_size = 32
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path, 
    verbose=1, 
    save_best_only=False,
    save_weights_only=True)

# %%
# Evaluate the model
#loss, acc = model.evaluate(validation_images, verbose=2)
#print("Untrained model, accuracy: {:5.2f}%".format(100 * acc))

# %%
history = model.fit(train_images,
    steps_per_epoch=len(train_images),
    validation_data=validation_images,
    validation_steps=len(validation_images),
    epochs=300,
    callbacks=[cp_callback])
# Out:
# Epoch 1/300
# 956/956 [==============================] - ETA: 0s - loss: 0.9397 - accuracy: 0.5626
# Epoch 1: saving model to /content/drive/My Drive/ml_project/Checkpoints/BasicCNN3training_1/cp.ckpt
# 956/956 [==============================] - 12742s 13s/step - loss: 0.9397 - accuracy: 0.5626 - val_loss: 0.6650 - val_accuracy: 0.7016
# Epoch 2/300
# 956/956 [==============================] - ETA: 0s - loss: 0.6322 - accuracy: 0.7194
# Epoch 2: saving model to /content/drive/My Drive/ml_project/Checkpoints/BasicCNN3training_1/cp.ckpt
# 956/956 [==============================] - 1081s 1s/step - loss: 0.6322 - accuracy: 0.7194 - val_loss: 0.4392 - val_accuracy: 0.8243
# Epoch 3/300
# 956/956 [==============================] - ETA: 0s - loss: 0.4643 - accuracy: 0.7971
# Epoch 3: saving model to /content/drive/My Drive/ml_project/Checkpoints/BasicCNN3training_1/cp.ckpt
# 956/956 [==============================] - 1092s 1s/step - loss: 0.4643 - accuracy: 0.7971 - val_loss: 0.3545 - val_accuracy: 0.8476
# Epoch 4/300
# 956/956 [==============================] - ETA: 0s - loss: 0.3743 - accuracy: 0.8409
# Epoch 4: saving model to /content/drive/My Drive/ml_project/Checkpoints/BasicCNN3training_1/cp.ckpt
# 956/956 [==============================] - 1116s 1s/step - loss: 0.3743 - accuracy: 0.8409 - val_loss: 0.2601 - val_accuracy: 0.8991
# Epoch 5/300
# 956/956 [==============================] - ETA: 0s - loss: 0.3145 - accuracy: 0.8696
# Epoch 5: saving model to /content/drive/My Drive/ml_project/Checkpoints/BasicCNN3training_1/cp.ckpt
# 956/956 [==============================] - 1184s 1s/step - loss: 0.3145 - accuracy: 0.8696 - val_loss: 0.2282 - val_accuracy: 0.9079
# Epoch 6/300
# 956/956 [==============================] - ETA: 0s - loss: 0.2765 - accuracy: 0.8874
# Epoch 6: saving model to /content/drive/My Drive/ml_project/Checkpoints/BasicCNN3training_1/cp.ckpt
# 956/956 [==============================] - 1152s 1s/step - loss: 0.2765 - accuracy: 0.8874 - val_loss: 0.1985 - val_accuracy: 0.9276
# Epoch 7/300
# 956/956 [==============================] - ETA: 0s - loss: 0.2426 - accuracy: 0.9004
# Epoch 7: saving model to /content/drive/My Drive/ml_project/Checkpoints/BasicCNN3training_1/cp.ckpt
# 956/956 [==============================] - 1111s 1s/step - loss: 0.2426 - accuracy: 0.9004 - val_loss: 0.1843 - val_accuracy: 0.9270
# Epoch 8/300
# 956/956 [==============================] - ETA: 0s - loss: 0.2177 - accuracy: 0.9106
# Epoch 8: saving model to /content/drive/My Drive/ml_project/Checkpoints/BasicCNN3training_1/cp.ckpt
# 956/956 [==============================] - 1107s 1s/step - loss: 0.2177 - accuracy: 0.9106 - val_loss: 0.1765 - val_accuracy: 0.9344
# Epoch 9/300
# 956/956 [==============================] - ETA: 0s - loss: 0.1993 - accuracy: 0.9203
# Epoch 9: saving model to /content/drive/My Drive/ml_project/Checkpoints/BasicCNN3training_1/cp.ckpt
# 956/956 [==============================] - 1105s 1s/step - loss: 0.1993 - accuracy: 0.9203 - val_loss: 0.1586 - val_accuracy: 0.9376
# Epoch 10/300
# 956/956 [==============================] - ETA: 0s - loss: 0.1842 - accuracy: 0.9262
# Epoch 10: saving model to /content/drive/My Drive/ml_project/Checkpoints/BasicCNN3training_1/cp.ckpt
# 956/956 [==============================] - 1111s 1s/step - loss: 0.1842 - accuracy: 0.9262 - val_loss: 0.1534 - val_accuracy: 0.9388
# Epoch 11/300
# 956/956 [==============================] - ETA: 0s - loss: 0.1742 - accuracy: 0.9321
# Epoch 11: saving model to /content/drive/My Drive/ml_project/Checkpoints/BasicCNN3training_1/cp.ckpt
# 956/956 [==============================] - 1127s 1s/step - loss: 0.1742 - accuracy: 0.9321 - val_loss: 0.1549 - val_accuracy: 0.9408
# Epoch 12/300
# 956/956 [==============================] - ETA: 0s - loss: 0.1580 - accuracy: 0.9377
# Epoch 12: saving model to /content/drive/My Drive/ml_project/Checkpoints/BasicCNN3training_1/cp.ckpt
# 956/956 [==============================] - 1141s 1s/step - loss: 0.1580 - accuracy: 0.9377 - val_loss: 0.1491 - val_accuracy: 0.9406
# Epoch 13/300
# 956/956 [==============================] - ETA: 0s - loss: 0.1533 - accuracy: 0.9404
# Epoch 13: saving model to /content/drive/My Drive/ml_project/Checkpoints/BasicCNN3training_1/cp.ckpt
# 956/956 [==============================] - 1099s 1s/step - loss: 0.1533 - accuracy: 0.9404 - val_loss: 0.1426 - val_accuracy: 0.9459
# Epoch 14/300
# 956/956 [==============================] - ETA: 0s - loss: 0.1390 - accuracy: 0.9463
# Epoch 14: saving model to /content/drive/My Drive/ml_project/Checkpoints/BasicCNN3training_1/cp.ckpt
# 956/956 [==============================] - 1109s 1s/step - loss: 0.1390 - accuracy: 0.9463 - val_loss: 0.1384 - val_accuracy: 0.9461
# Epoch 15/300
# 956/956 [==============================] - ETA: 0s - loss: 0.1330 - accuracy: 0.9494
# Epoch 15: saving model to /content/drive/My Drive/ml_project/Checkpoints/BasicCNN3training_1/cp.ckpt
# 956/956 [==============================] - 1091s 1s/step - loss: 0.1330 - accuracy: 0.9494 - val_loss: 0.1402 - val_accuracy: 0.9479
# Epoch 16/300
# 956/956 [==============================] - ETA: 0s - loss: 0.1272 - accuracy: 0.9510
# Epoch 16: saving model to /content/drive/My Drive/ml_project/Checkpoints/BasicCNN3training_1/cp.ckpt
# 956/956 [==============================] - 1104s 1s/step - loss: 0.1272 - accuracy: 0.9510 - val_loss: 0.1518 - val_accuracy: 0.9441
# Epoch 17/300
# 956/956 [==============================] - ETA: 0s - loss: 0.1190 - accuracy: 0.9546
# Epoch 17: saving model to /content/drive/My Drive/ml_project/Checkpoints/BasicCNN3training_1/cp.ckpt
# 956/956 [==============================] - 1116s 1s/step - loss: 0.1190 - accuracy: 0.9546 - val_loss: 0.1500 - val_accuracy: 0.9464
# Epoch 18/300
# 956/956 [==============================] - ETA: 0s - loss: 0.1149 - accuracy: 0.9564
# Epoch 18: saving model to /content/drive/My Drive/ml_project/Checkpoints/BasicCNN3training_1/cp.ckpt
# 956/956 [==============================] - 1099s 1s/step - loss: 0.1149 - accuracy: 0.9564 - val_loss: 0.1359 - val_accuracy: 0.9491
# Epoch 19/300
# 956/956 [==============================] - ETA: 0s - loss: 0.1075 - accuracy: 0.9601
# Epoch 19: saving model to /content/drive/My Drive/ml_project/Checkpoints/BasicCNN3training_1/cp.ckpt
# 956/956 [==============================] - 1113s 1s/step - loss: 0.1075 - accuracy: 0.9601 - val_loss: 0.1254 - val_accuracy: 0.9547
# Epoch 20/300
# 956/956 [==============================] - ETA: 0s - loss: 0.1040 - accuracy: 0.9614
# Epoch 20: saving model to /content/drive/My Drive/ml_project/Checkpoints/BasicCNN3training_1/cp.ckpt
# 956/956 [==============================] - 1108s 1s/step - loss: 0.1040 - accuracy: 0.9614 - val_loss: 0.1339 - val_accuracy: 0.9497
# Epoch 21/300
# 956/956 [==============================] - ETA: 0s - loss: 0.1027 - accuracy: 0.9624
# Epoch 21: saving model to /content/drive/My Drive/ml_project/Checkpoints/BasicCNN3training_1/cp.ckpt
# 956/956 [==============================] - 1103s 1s/step - loss: 0.1027 - accuracy: 0.9624 - val_loss: 0.1179 - val_accuracy: 0.9535
# Epoch 22/300
# 956/956 [==============================] - ETA: 0s - loss: 0.0992 - accuracy: 0.9632
# Epoch 22: saving model to /content/drive/My Drive/ml_project/Checkpoints/BasicCNN3training_1/cp.ckpt
# 956/956 [==============================] - 1108s 1s/step - loss: 0.0992 - accuracy: 0.9632 - val_loss: 0.1156 - val_accuracy: 0.9553
# Epoch 23/300
# 956/956 [==============================] - ETA: 0s - loss: 0.0897 - accuracy: 0.9684
# Epoch 23: saving model to /content/drive/My Drive/ml_project/Checkpoints/BasicCNN3training_1/cp.ckpt
# 956/956 [==============================] - 1125s 1s/step - loss: 0.0897 - accuracy: 0.9684 - val_loss: 0.1173 - val_accuracy: 0.9585
# Epoch 24/300
# 956/956 [==============================] - ETA: 0s - loss: 0.0891 - accuracy: 0.9667
# Epoch 24: saving model to /content/drive/My Drive/ml_project/Checkpoints/BasicCNN3training_1/cp.ckpt
# 956/956 [==============================] - 1134s 1s/step - loss: 0.0891 - accuracy: 0.9667 - val_loss: 0.1228 - val_accuracy: 0.9541
# Epoch 25/300
# 956/956 [==============================] - ETA: 0s - loss: 0.0885 - accuracy: 0.9669
# Epoch 25: saving model to /content/drive/My Drive/ml_project/Checkpoints/BasicCNN3training_1/cp.ckpt
# 956/956 [==============================] - 1135s 1s/step - loss: 0.0885 - accuracy: 0.9669 - val_loss: 0.1076 - val_accuracy: 0.9588
# Epoch 26/300
# 956/956 [==============================] - ETA: 0s - loss: 0.0835 - accuracy: 0.9692
# Epoch 26: saving model to /content/drive/My Drive/ml_project/Checkpoints/BasicCNN3training_1/cp.ckpt
# 956/956 [==============================] - 1128s 1s/step - loss: 0.0835 - accuracy: 0.9692 - val_loss: 0.1481 - val_accuracy: 0.9453
# Epoch 27/300
# 956/956 [==============================] - ETA: 0s - loss: 0.0846 - accuracy: 0.9686
# Epoch 27: saving model to /content/drive/My Drive/ml_project/Checkpoints/BasicCNN3training_1/cp.ckpt
# 956/956 [==============================] - 1130s 1s/step - loss: 0.0846 - accuracy: 0.9686 - val_loss: 0.1141 - val_accuracy: 0.9606
# Epoch 28/300
# 956/956 [==============================] - ETA: 0s - loss: 0.0822 - accuracy: 0.9709
# Epoch 28: saving model to /content/drive/My Drive/ml_project/Checkpoints/BasicCNN3training_1/cp.ckpt
# 956/956 [==============================] - 1130s 1s/step - loss: 0.0822 - accuracy: 0.9709 - val_loss: 0.1046 - val_accuracy: 0.9594
# Epoch 29/300
# 956/956 [==============================] - ETA: 0s - loss: 0.0752 - accuracy: 0.9717
# Epoch 29: saving model to /content/drive/My Drive/ml_project/Checkpoints/BasicCNN3training_1/cp.ckpt
# 956/956 [==============================] - 1128s 1s/step - loss: 0.0752 - accuracy: 0.9717 - val_loss: 0.1071 - val_accuracy: 0.9606
# Epoch 30/300
# 956/956 [==============================] - ETA: 0s - loss: 0.0763 - accuracy: 0.9729
# Epoch 30: saving model to /content/drive/My Drive/ml_project/Checkpoints/BasicCNN3training_1/cp.ckpt
# 956/956 [==============================] - 1137s 1s/step - loss: 0.0763 - accuracy: 0.9729 - val_loss: 0.1205 - val_accuracy: 0.9585
# Epoch 31/300
# 956/956 [==============================] - ETA: 0s - loss: 0.0737 - accuracy: 0.9736
# Epoch 31: saving model to /content/drive/My Drive/ml_project/Checkpoints/BasicCNN3training_1/cp.ckpt
# 956/956 [==============================] - 1150s 1s/step - loss: 0.0737 - accuracy: 0.9736 - val_loss: 0.1148 - val_accuracy: 0.9620
# Epoch 32/300
# 956/956 [==============================] - ETA: 0s - loss: 0.0732 - accuracy: 0.9730
# Epoch 32: saving model to /content/drive/My Drive/ml_project/Checkpoints/BasicCNN3training_1/cp.ckpt
# 956/956 [==============================] - 1147s 1s/step - loss: 0.0732 - accuracy: 0.9730 - val_loss: 0.1209 - val_accuracy: 0.9600
# Epoch 33/300
# 956/956 [==============================] - ETA: 0s - loss: 0.0749 - accuracy: 0.9721
# Epoch 33: saving model to /content/drive/My Drive/ml_project/Checkpoints/BasicCNN3training_1/cp.ckpt
# 956/956 [==============================] - 1149s 1s/step - loss: 0.0749 - accuracy: 0.9721 - val_loss: 0.1111 - val_accuracy: 0.9597
# Epoch 34/300
# 956/956 [==============================] - ETA: 0s - loss: 0.0747 - accuracy: 0.9732
# Epoch 34: saving model to /content/drive/My Drive/ml_project/Checkpoints/BasicCNN3training_1/cp.ckpt
# 956/956 [==============================] - 1151s 1s/step - loss: 0.0747 - accuracy: 0.9732 - val_loss: 0.1050 - val_accuracy: 0.9635
# Epoch 35/300
# 956/956 [==============================] - ETA: 0s - loss: 0.0695 - accuracy: 0.9752
# Epoch 35: saving model to /content/drive/My Drive/ml_project/Checkpoints/BasicCNN3training_1/cp.ckpt
# 956/956 [==============================] - 1155s 1s/step - loss: 0.0695 - accuracy: 0.9752 - val_loss: 0.1171 - val_accuracy: 0.9570
# Epoch 36/300
# 956/956 [==============================] - ETA: 0s - loss: 0.0582 - accuracy: 0.9797
# Epoch 36: saving model to /content/drive/My Drive/ml_project/Checkpoints/BasicCNN3training_1/cp.ckpt
# 956/956 [==============================] - 1154s 1s/step - loss: 0.0582 - accuracy: 0.9797 - val_loss: 0.1173 - val_accuracy: 0.9585
# Epoch 37/300
# 181/956 [====>.........................] - ETA: 15:07 - loss: 0.0507 - accuracy: 0.9817

# %% [markdown]
# basic model overfit starting from epoch 9

# %%
#Accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# 2 following cells are for loading latest trained models

# %%
# Create a basic model instance
#model = create_model()

# Evaluate the model
#loss, acc = model.evaluate(validation_images, verbose=2)
#print("Untrained model, accuracy: {:5.2f}%".format(100 * acc))

# %%
# Loads the weights
#p='/content/drive/My Drive/ml_project/Checkpoints/BasicCNN-training/cp-"

#fill in the best model filename like 0004
#best_checkpoint_path=p+""+"".ckpt"
#latest = tf.train.latest_checkpoint(checkpoint_dir)
#model.load_weights(latest)

# Re-evaluate the model
#loss, acc = model.evaluate(validation_images, verbose=2)
#print("Restored model, accuracy: {:5.2f}%".format(100 * acc))
